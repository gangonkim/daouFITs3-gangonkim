# %% [markdown]
# <a href="https://colab.research.google.com/github/gangonkim/daouFITs3-gangonkim/blob/%EC%8B%A4%EC%8A%B5/%EC%8B%A4%EC%8A%B5%EA%B3%BC%EC%A0%9C12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#배열 초기화
arr = [1, 2, 3, 4, 5]

# %%
#배열 요소 접근
arr[0], arr[3], arr[-1]
# Out:
# (1, 4, 5)

# %%
#배열의 크기 구하기
len(arr)
# Out:
# 5
